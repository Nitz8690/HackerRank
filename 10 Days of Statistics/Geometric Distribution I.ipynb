# %% [markdown]
# ## Day 4: Geometric Distribution I

# %% [markdown]
# ![Screenshot%20from%202020-10-23%2016-50-54.png](attachment:Screenshot%20from%202020-10-23%2016-50-54.png)

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT


q = 1/3.0
p = 1-q

N = 5

print(round(q * p**(N-1),3))
