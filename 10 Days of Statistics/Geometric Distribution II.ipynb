# %% [markdown]
# ## Day 4: Geometric Distribution II

# %% [markdown]
# ![Screenshot%20from%202020-10-23%2016-52-01.png](attachment:Screenshot%20from%202020-10-23%2016-52-01.png)

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT

p = 1/3.0
q = 1-p
N = 5

sum = p * (1 + q**1 + q**2 + q**3 + q**4)

print(round(sum,3))
# Out:
# 0.868
