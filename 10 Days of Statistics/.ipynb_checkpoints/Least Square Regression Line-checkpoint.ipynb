# %% [markdown]
# ### Day 8: Least Square Regression Line

# %% [markdown]
# ![Screenshot%20from%202020-10-28%2018-30-36.png](attachment:Screenshot%20from%202020-10-28%2018-30-36.png)

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT

L = [ list( map( float, input().strip().split(" ") ) ) for i in range(5) ]
#print(L)

x = [ L[i][0] for i in range(5) ]
#print(x)

y = [ L[i][1] for i in range(5) ]
#print(y)

xiyi = [ x[i]*y[i] for i in range(len(x)) ]
xisq = [ x[i]**2 for i in range(len(x)) ]
xmean = sum(x)/5
ymean = sum(y)/5

b = (5*sum(xiyi)-sum(x)*sum(y)) / (5*sum(xisq)-sum(x)**2)
a = ymean - b*xmean

print('%.3f' % (a+80*b))
# Out:
# 95 85
# 85 95
# 80 70
# 70 65
# 60 70
# 78.288
