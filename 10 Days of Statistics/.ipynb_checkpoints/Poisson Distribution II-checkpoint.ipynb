# %% [markdown]
# ## Day 5: Poisson Distribution II

# %% [markdown]
# ![Screenshot%20from%202020-10-25%2000-25-23.png](attachment:Screenshot%20from%202020-10-25%2000-25-23.png)

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT

from math import factorial,exp

A = 0.88
B = 1.55

C_A = 160+40*(A**2+A)
C_B = 128+40*(B**2+B)

print(round(C_A,3))
print(round(C_B,3))
# Out:
# 226.176
# 286.1
