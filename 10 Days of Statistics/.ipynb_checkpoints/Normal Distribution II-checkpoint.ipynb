# %% [markdown]
# ## Day 5: Normal Distribution II

# %% [markdown]
# ![Screenshot%20from%202020-10-25%2000-32-09.png](attachment:Screenshot%20from%202020-10-25%2000-32-09.png)

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT

import math

def cdf(x, m, sd):
    return 0.5 * (1 + math.erf((x - m)/(sd * math.sqrt(2))))
    

m = 70
sd = 10

val_A = 80
val_pass = 60

print("%.2f" % (round(1 - cdf(80, m, sd) + cdf(0, m, sd), 4) * 100))
print("%.2f" % (round(1 - cdf(60, m, sd), 4) * 100))
print("%.2f" % (round(cdf(60, m, sd), 4) * 100))
# Out:
# 15.87
# 84.13
# 15.87
