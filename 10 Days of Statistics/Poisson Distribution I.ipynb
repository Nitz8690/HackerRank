# %% [markdown]
# ## Day 5: Poisson Distribution I

# %% [markdown]
# ![Screenshot%20from%202020-10-25%2000-23-47.png](attachment:Screenshot%20from%202020-10-25%2000-23-47.png)

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT

from math import e, factorial


def p(l,k):
    return (e**(-l)) * (l**k) / factorial(k)

print(round(p(2.5,5),3))
# Out:
# 0.067
