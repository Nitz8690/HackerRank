# %% [markdown]
# ## Day 6: The Central Limit Theorem III

# %% [markdown]
# ![Screenshot%20from%202020-10-25%2013-45-34.png](attachment:Screenshot%20from%202020-10-25%2013-45-34.png)

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT

n = 100
m = 500
sd = 80
a = 0.95
z = 1.96

print("%.2f" % round(m - z * sd/10, 2))
print("%.2f" % round(m + z * sd/10, 2))
# Out:
# 484.32
# 515.68
