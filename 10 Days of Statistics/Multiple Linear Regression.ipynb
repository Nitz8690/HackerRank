# %% [markdown]
# ### Day 9: Multiple Linear Regression

# %% [markdown]
# ![Screenshot%20from%202020-10-28%2018-36-39.png](attachment:Screenshot%20from%202020-10-28%2018-36-39.png)

# %% [markdown]
# ![Screenshot%20from%202020-10-28%2018-36-54.png](attachment:Screenshot%20from%202020-10-28%2018-36-54.png)

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT

from sklearn import linear_model

n,m = [int(i) for i in input().strip().split(' ')]

x_arr = []
y_arr = []
#print(n,m)
for i in range(m):
    temp = [float(j) for j in input().strip().split(' ')]
    y_arr.append(temp[-1])
    x_arr.append(temp[0:-1])

#print(x_arr)
#print(y_arr)

lm = linear_model.LinearRegression()
lm.fit(x_arr, y_arr)
a = lm.intercept_
b = lm.coef_
#print(a, b[0], b[1])

q = int(input().strip())


for i in range(q):
    x_test = [float(j) for j in input().strip().split(' ')]
    val = a
    for j in range(n):
        val += b[j]*x_test[j]
    print(val)
# Out:
# 2 7
# 0.18 0.89 109.85
# 1.0 0.26 155.72
# 0.92 0.11 137.66
# 0.07 0.37 76.17
# 0.85 0.16 139.75
# 0.99 0.41 162.6
# 0.87 0.47 151.77
# 4
# 0.49 0.18
# 105.21455835106946
# 0.57 0.83
# 142.67095130729922
# 0.56 0.64
# 132.93605469124694
# 0.76 0.18
# 129.70175404502453
